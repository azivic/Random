# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68086b17-5ead-4e47-9472-cbc64ec3241a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68086b17-5ead-4e47-9472-cbc64ec3241a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1200px-OpenCV_Logo_with_text_svg_version.svg.png to 1200px-OpenCV_Logo_with_text_svg_version.svg.png

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
#read
image=cv.imread("1200px-OpenCV_Logo_with_text_svg_version.svg.png")

#resize
image = cv.resize(image, (500,600), interpolation=cv.INTER_CUBIC)

cv2_imshow(image) #cv.imshow('name of the pic', variable)
# Out:
# <PIL.Image.Image image mode=RGB size=500x600 at 0x7F61CE26F550>

# %%
cropped = image[0:220, 2:450]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=448x220 at 0x7F61CD9E5B90>

# %%
cropped.shape
# Out:
# (220, 448, 3)

# %%
#converting to grayscale
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x600 at 0x7F4E95B35750>

# %%
#Blur 
blur = cv.GaussianBlur(image, (7,7), cv.BORDER_DEFAULT)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=RGB size=500x600 at 0x7F4E90BBA890>

# %%
# Edge Cascade
canny = cv.Canny(blur, 125, 175)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=500x600 at 0x7F4E90A26DD0>

# %%
blank = np.zeros((300,600,3), dtype='uint8')
#draw
blank[120:250, 100:350] = 10,155,208
cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7F61CD9EE710>

# %%
cv.putText(blank, 'It works?', (100,285), cv.FONT_HERSHEY_TRIPLEX, 1.0, (0,200,120), 2)
cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7F61CD9EEC90>

# %%
cv.waitKey(0)
# Out:
# -1

# %%
#translation
def translate(image, x, y):
    transMat = np.float32([[1,0,x],[0,1,y]])
    dimensions = (image.shape[1], image.shape[0])
    return cv.warpAffine(image, transMat, dimensions)
translated = translate(image, -70, 0)
cv2_imshow(translated)
# Out:
# <PIL.Image.Image image mode=RGB size=500x600 at 0x7F4E909DCDD0>

# %%
# Flipping
flip = cv.flip(image, -1)
cv2_imshow(flip)
# Out:
# <PIL.Image.Image image mode=RGB size=500x600 at 0x7F61CD9801D0>

# %%
circle = cv.circle(blank.copy(), (image.shape[1]//2 +45, image.shape[0]//2), 70, 200, -1)

rectangle = cv.rectangle(blank.copy(), (190,10), (380,200), 125, -1)

cv2_imshow(rectangle)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7F61CD929A90>
